# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Srikanth A**
#
# Student

# %% [markdown]
# _I am interested in Data Science because I would love to work with data_

# %% [markdown]
# ### The below should print 'Hello World'

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# > You miss 100% of the shots you don't take
# >
#  - Wayne Gretzky
#
#
# <hr>
#
# Made with <3 [My Github](https://github.com/srikaanthh)
