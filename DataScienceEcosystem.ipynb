# %% [markdown]
# # Data Science Tools and Eco-System

# %% [markdown]
# ## Introduction
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ## Data Science Languages
# - Python
# - R
# - Julia

# %% [markdown]
# ## Data Science Libraries
# - Pandas
# - NumPy
# - Matplotlib
# - Seaborn
# - scikit-learn

# %% [markdown]
# ## Data Science Tools
#
# | Tool         | Description                          |
# |--------------|--------------------------------------|
# | Jupyter      | Interactive notebooks for coding     |
# | VS Code      | Integrated development environment   |
# | Git          | Version control system               |
# | Docker       | Containerization platform            |
# | TensorFlow   | Machine learning framework           |
# | Tableau      | Data visualization tool              |

# %% [markdown]
# ## Arithmetic Expressions
# We will demonstrate basic arithmetic operations such as addition, multiplication, and unit conversion in this notebook.

# %%
# This is a simple arithmetic expression to multiply then add integers.
result = (3 * 4) + 5
result
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60.
minutes = 200
hours = minutes / 60
hours
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Objectives:
#
# - List popular languages for Data Science.
# - Identify essential libraries used in Data Science.
# - Demonstrate basic arithmetic operations.

# %% [markdown]
# ## Author
# SRIKANTH A
